# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# We set the grafic stille
sns.set_style("whitegrid")

# %%
# Loads the file CSV
df = pd.read_csv("listings.csv")

# Shows the farst 5 rows
df.head()
# Out:
#       id                                               name  host_id  \
# 0   6983                               Copenhagen 'N Livin'    16774
# 1  26057                Lovely house - most attractive area   109777
# 2  26473          City Centre Townhouse Sleeps 1-10 persons   112210
# 3  29118                    Best Location in Cool Istedgade   125230
# 4  31094  Beautiful, spacious, central, renovated Penthouse   129976
#
#   host_name  neighbourhood_group              neighbourhood   latitude  \
# 0     Simon                  NaN                    Nrrebro  55.686410
# 1      Kari                  NaN                   Indre By  55.693070
# 2     Julia                  NaN                   Indre By  55.676020
# 3      Nana                  NaN  Vesterbro-Kongens Enghave  55.670230
# 4      Ebbe                  NaN  Vesterbro-Kongens Enghave  55.666602
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
# Number of rows and columns
df.shape

# Data types and missing values
df.info()

# Summary statistics (only for numeric columns)
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13815 entries, 0 to 13814
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              13815 non-null  int64
#  1   name                            13815 non-null  object
#  2   host_id                         13815 non-null  int64
#  3   host_name                       13814 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   13815 non-null  object
#  6   latitude                        13815 non-null  float64
#  7   longitude                       13815 non-null  float64
#  8   room_type                       13815 non-null  object
#  9   price                           13815 non-null  int64
#  10  minimum_nights                  13815 non-null  int64
#  11  number_of_reviews               13815 non-null  int64
# ...

# %%
# Count missing values per column
df.isnull().sum().sort_values(ascending=False)
# Out:
# license                           13815
# neighbourhood_group               13815
# reviews_per_month                  1645
# last_review                        1645
# host_name                             1
# minimum_nights                        0
# number_of_reviews_ltm                 0
# availability_365                      0
# calculated_host_listings_count        0
# number_of_reviews                     0
# id                                    0
# name                                  0
# room_type                             0
# longitude                             0
# latitude                              0
# neighbourhood                         0
# host_id                               0
# price                                 0
# dtype: int64

# %%
# Drop columns you won't use
df_cleaned = df.drop(columns=['id', 'host_name', 'host_id', 'last_review'])

# Optional: Keep only listings with price > 0
df_cleaned = df_cleaned[df_cleaned['price'] > 0]

# %%
df = pd.read_csv('listings.csv')  # file name

# %%
df['price'].head(10)
# Out:
# 0     898
# 1    2600
# 2    3250
# 3     725
# 4    1954
# 5    1280
# 6     617
# 7    1000
# 8    2916
# 9    1900
# Name: price, dtype: int64

# %%
# Clean colon price: delite lines and convert in float
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\dqdqqqqqdasd\AppData\Local\Temp\ipykernel_22844\2888108589.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Its not nesesere to reconverce with replace/regex!

# Delete unnecessary coloans
df_cleaned = df.drop(columns=['id', 'host_name', 'host_id', 'last_review'])

# 'keep the rows were is les then > 0
df_cleaned = df_cleaned[df_cleaned['price'] > 0]

# Show wath I have
df_cleaned.head()
# Out:
#                                                 name  neighbourhood_group  \
# 0                               Copenhagen 'N Livin'                  NaN
# 1                Lovely house - most attractive area                  NaN
# 2          City Centre Townhouse Sleeps 1-10 persons                  NaN
# 3                    Best Location in Cool Istedgade                  NaN
# 4  Beautiful, spacious, central, renovated Penthouse                  NaN
#
#                neighbourhood   latitude  longitude        room_type   price  \
# 0                    Nrrebro  55.686410  12.547410  Entire home/apt   898.0
# 1                   Indre By  55.693070  12.576490  Entire home/apt  2600.0
# 2                   Indre By  55.676020  12.575400  Entire home/apt  3250.0
# 3  Vesterbro-Kongens Enghave  55.670230  12.555040  Entire home/apt   725.0
# 4  Vesterbro-Kongens Enghave  55.666602  12.555283  Entire home/apt  1954.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
df_cleaned.to_csv('listings_cleaned.csv', index=False)
